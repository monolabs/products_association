# %%
import pandas as pd
# pd.set_option('display.max_columns', None)
import numpy as np
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.preprocessing import OneHotEncoder, normalize
from sklearn.metrics import f1_score, accuracy_score, confusion_matrix, recall_score, precision_score
from scipy.sparse import csr_matrix
import xgboost as xgb
from xgboost import XGBClassifier
import pickle
import time

# %%
# load feature importance
fi = pd.read_csv('../results/xgb_feature_importances_v1_top500.csv', index_col=0)
products = pd.read_csv('../data/products.csv', index_col=0, usecols=['product_id', 'product_name'])

# build product name dictionary for product_ids in strings
products_dict_string = {}
for k, v in products.to_dict()['product_name'].items():
    products_dict_string[str(k)] = v

fi = fi.rename(columns=products_dict_string, index=products.to_dict()['product_name'])
fi.head()
# Out:
#                         Bag of Organic Bananas  Organic Strawberries  \
# Banana                            16429.526711           1279.071116
# Bag of Organic Bananas                     NaN           2301.037867
# Organic Strawberries               2576.305969                   NaN
# Organic Baby Spinach               1699.331320           2290.482298
# Organic Hass Avocado               9399.550122           4647.737054
#
#                         Organic Baby Spinach  Organic Hass Avocado  \
# Banana                            517.772529             39.502174
# Bag of Organic Bananas           1715.161014           4171.241089
# Organic Strawberries             1995.664821           2642.691564
# Organic Baby Spinach                     NaN           3773.820365
# Organic Hass Avocado             3132.413388                   NaN
#
#                         Organic Avocado  Large Lemon  Strawberries  \
# Banana                      2750.613134   775.537591   1600.779739
# Bag of Organic Bananas        27.711317    18.298088     29.048433
# Organic Strawberries        1013.659842    31.463527   2321.034563
# Organic Baby Spinach        5673.249576  1449.552438     27.865870
# Organic Hass Avocado        3506.243967   134.378344    178.815864
#
#                               Limes  Organic Whole Milk  Organic Raspberries  \
# Banana                    61.527677          804.173961            36.919135
# Bag of Organic Bananas    24.578167          770.728439          1822.199426
# Organic Strawberries     166.930545         1994.481109          5175.236566
# Organic Baby Spinach     346.613926          432.487979            17.776998
# Organic Hass Avocado    2337.994997           45.859021          2778.636262
#
#                         ...  order_hod_15  order_hod_16  order_hod_17  \
# Banana                  ...           NaN           NaN           NaN
# Bag of Organic Bananas  ...           NaN           NaN           NaN
# Organic Strawberries    ...           NaN           NaN           NaN
# Organic Baby Spinach    ...           NaN           NaN           NaN
# Organic Hass Avocado    ...           NaN           NaN           NaN
#
#                         order_hod_18  order_hod_19  order_hod_20  \
# Banana                           NaN           NaN           NaN
# Bag of Organic Bananas           NaN           NaN           NaN
# Organic Strawberries             NaN           NaN           NaN
# Organic Baby Spinach             NaN           NaN           NaN
# Organic Hass Avocado             NaN           NaN           NaN
#
#                         order_hod_21  order_hod_22  order_hod_23        Banana
# Banana                           NaN           NaN           NaN           NaN
# Bag of Organic Bananas           NaN           NaN           NaN  22385.882321
# Organic Strawberries             NaN           NaN           NaN   1543.809114
# Organic Baby Spinach             NaN           NaN           NaN    499.537555
# Organic Hass Avocado             NaN           NaN           NaN     74.096809
#
# [5 rows x 531 columns]

# %%
# normalize values
arr = fi.fillna(0).values
arr = normalize(arr, norm='max', axis=1)
fi_norm = pd.DataFrame(arr, index=fi.index, columns=fi.columns)
display(fi_norm.head())
fi_norm.to_csv('../results/xgb_feature_importances_v1_top500_norm.csv')
# Out:
#                         Bag of Organic Bananas  Organic Strawberries  \
# Banana                                1.000000              0.077852
# Bag of Organic Bananas                0.000000              0.102790
# Organic Strawberries                  0.497814              0.000000
# Organic Baby Spinach                  0.276900              0.373226
# Organic Hass Avocado                  1.000000              0.494464
#
#                         Organic Baby Spinach  Organic Hass Avocado  \
# Banana                              0.031515              0.002404
# Bag of Organic Bananas              0.076618              0.186334
# Organic Strawberries                0.385618              0.510642
# Organic Baby Spinach                0.000000              0.614931
# Organic Hass Avocado                0.333251              0.000000
#
#                         Organic Avocado  Large Lemon  Strawberries     Limes  \
# Banana                         0.167419     0.047204      0.097433  0.003745
# Bag of Organic Bananas         0.001238     0.000817      0.001298  0.001098
# Organic Strawberries           0.195867     0.006080      0.448489  0.032256
# Organic Baby Spinach           0.924437     0.236200      0.004541  0.056480
# Organic Hass Avocado           0.373023     0.014296      0.019024  0.248735
#
#                         Organic Whole Milk  Organic Raspberries  ...  \
# Banana                            0.048947             0.002247  ...
# Bag of Organic Bananas            0.034429             0.081399  ...
# Organic Strawberries              0.385389             1.000000  ...
# Organic Baby Spinach              0.070472             0.002897  ...
# Organic Hass Avocado              0.004879             0.295614  ...
#
#                         order_hod_15  order_hod_16  order_hod_17  \
# Banana                           0.0           0.0           0.0
# Bag of Organic Bananas           0.0           0.0           0.0
# Organic Strawberries             0.0           0.0           0.0
# Organic Baby Spinach             0.0           0.0           0.0
# Organic Hass Avocado             0.0           0.0           0.0
#
#                         order_hod_18  order_hod_19  order_hod_20  \
# Banana                           0.0           0.0           0.0
# Bag of Organic Bananas           0.0           0.0           0.0
# Organic Strawberries             0.0           0.0           0.0
# Organic Baby Spinach             0.0           0.0           0.0
# Organic Hass Avocado             0.0           0.0           0.0
#
#                         order_hod_21  order_hod_22  order_hod_23    Banana
# Banana                           0.0           0.0           0.0  0.000000
# Bag of Organic Bananas           0.0           0.0           0.0  1.000000
# Organic Strawberries             0.0           0.0           0.0  0.298307
# Organic Baby Spinach             0.0           0.0           0.0  0.081398
# Organic Hass Avocado             0.0           0.0           0.0  0.007883
#
# [5 rows x 531 columns]
